# %%
import sys
import os
import glob
import pandas as pd

# %%
file_cluster = glob.glob('../data/clean/cp_hourly/*.csv')

# %%
generation = pd.read_csv('../generation_test.tab', sep='\t', index_col=0)
generation.head()
# Out:
#                                         gen_tech  gen_load_zone  \
# GENERATION_PROJECT
# bioenergy_diesel_001            bioenergy_diesel  01-hermosillo
# bioenergy_natural_gas_001  bioenergy_natural_gas  01-hermosillo
# bioenergy_fuel_oil_001        bioenergy_fuel_oil  01-hermosillo
# bioenergy_thermal_001          bioenergy_thermal  01-hermosillo
# bioenergy_natural_gas_001  bioenergy_natural_gas  01-hermosillo
#
#                            gen_connect_cost_per_mw gen_full_load_heat_rate  \
# GENERATION_PROJECT
# bioenergy_diesel_001                     99048.565             46.26784408
# bioenergy_natural_gas_001                99048.565             9.163728341
# bioenergy_fuel_oil_001                   99048.565             45.99832266
# bioenergy_thermal_001                    99048.565             9.163728341
# bioenergy_natural_gas_001                99048.565             9.163728341
#
#                            gen_variable_om gen_capacity_limit_mw  \
# GENERATION_PROJECT
# bioenergy_diesel_001                  3.94                     .
# bioenergy_natural_gas_001             4.37                     .
# bioenergy_fuel_oil_001                3.94                     .
# bioenergy_thermal_001                 4.37                     .
# bioenergy_natural_gas_001             4.37                     .
#
#                           gen_energy_source  gen_min_build_capacity  \
# GENERATION_PROJECT
# bioenergy_diesel_001                 diesel                       0
# bioenergy_natural_gas_001       natural_gas                       0
# bioenergy_fuel_oil_001             fuel_oil                       0
# bioenergy_thermal_001           natural_gas                       0
# bioenergy_natural_gas_001       natural_gas                       0
#
#                            gen_scheduled_outage_rate  gen_forced_outage_rate  \
# GENERATION_PROJECT
# bioenergy_diesel_001                          0.1144                  0.1144
# bioenergy_natural_gas_001                     0.1123                  0.1123
# bioenergy_fuel_oil_001                        0.1144                  0.1144
# bioenergy_thermal_001                         0.0696                  0.0696
# bioenergy_natural_gas_001                     0.0696                  0.0696
#
#                            gen_max_age gen_unit_size  \
# GENERATION_PROJECT
# bioenergy_diesel_001                20             .
# bioenergy_natural_gas_001           20             .
# bioenergy_fuel_oil_001              20             .
# bioenergy_thermal_001               30             .
# bioenergy_natural_gas_001           30             .
#
#                           gen_ccs_capture_efficiency gen_ccs_energy_load  \
# GENERATION_PROJECT
# bioenergy_diesel_001                               .                   .
# bioenergy_natural_gas_001                          .                   .
# bioenergy_fuel_oil_001                             .                   .
# bioenergy_thermal_001                              .                   .
# bioenergy_natural_gas_001                          .                   .
#
#                           gen_storage_efficiency gen_store_to_release_ratio  \
# GENERATION_PROJECT
# bioenergy_diesel_001                           .                          .
# bioenergy_natural_gas_001                      .                          .
# bioenergy_fuel_oil_001                         .                          .
# bioenergy_thermal_001                          .                          .
# bioenergy_natural_gas_001                      .                          .
#
#                            gen_is_variable  gen_is_baseload  gen_is_cogen
# GENERATION_PROJECT
# bioenergy_diesel_001                     0                1             0
# bioenergy_natural_gas_001                0                1             0
# bioenergy_fuel_oil_001                   0                1             0
# bioenergy_thermal_001                    0                1             0
# bioenergy_natural_gas_001                0                1             0

# %%
generation_wind = generation.loc[generation['gen_tech'].isin(['wind', 'solarpv', 'solarpv_distributed'])]
generation_wind.head()
# Out:
#                                     gen_tech  gen_load_zone  \
# GENERATION_PROJECT
# solarpv_001                          solarpv  01-hermosillo
# solarpv_distributed_001  solarpv_distributed  01-hermosillo
# wind_001                                wind  01-hermosillo
# solarpv_002                          solarpv     02-cananea
# solarpv_distributed_002  solarpv_distributed     02-cananea
#
#                          gen_connect_cost_per_mw gen_full_load_heat_rate  \
# GENERATION_PROJECT
# solarpv_001                            99048.565                       .
# solarpv_distributed_001                99048.565                       .
# wind_001                               99048.565                       .
# solarpv_002                            99048.565                       .
# solarpv_distributed_002                99048.565                       .
#
#                          gen_variable_om gen_capacity_limit_mw  \
# GENERATION_PROJECT
# solarpv_001                          0.0                     .
# solarpv_distributed_001              0.0                     .
# wind_001                             0.0                     .
# solarpv_002                          0.0                     .
# solarpv_distributed_002              0.0                     .
#
#                          gen_energy_source  gen_min_build_capacity  \
# GENERATION_PROJECT
# solarpv_001                          solar                       0
# solarpv_distributed_001  solar_distributed                       0
# wind_001                              wind                       0
# solarpv_002                          solar                       0
# solarpv_distributed_002  solar_distributed                       0
#
#                          gen_scheduled_outage_rate  gen_forced_outage_rate  \
# GENERATION_PROJECT
# solarpv_001                                    0.0                     0.0
# solarpv_distributed_001                        0.0                     0.0
# wind_001                                       0.0                     0.0
# solarpv_002                                    0.0                     0.0
# solarpv_distributed_002                        0.0                     0.0
#
#                          gen_max_age gen_unit_size gen_ccs_capture_efficiency  \
# GENERATION_PROJECT
# solarpv_001                       25             .                          .
# solarpv_distributed_001           25             .                          .
# wind_001                          25             .                          .
# solarpv_002                       25             .                          .
# solarpv_distributed_002           25             .                          .
#
#                         gen_ccs_energy_load gen_storage_efficiency  \
# GENERATION_PROJECT
# solarpv_001                               .                      .
# solarpv_distributed_001                   .                      .
# wind_001                                  .                      .
# solarpv_002                               .                      .
# solarpv_distributed_002                   .                      .
#
#                         gen_store_to_release_ratio  gen_is_variable  \
# GENERATION_PROJECT
# solarpv_001                                      .                1
# solarpv_distributed_001                          .                1
# wind_001                                         .                1
# solarpv_002                                      .                1
# solarpv_distributed_002                          .                1
#
#                          gen_is_baseload  gen_is_cogen
# GENERATION_PROJECT
# solarpv_001                            0             0
# solarpv_distributed_001                0             0
# wind_001                               0             0
# solarpv_002                            0             0
# solarpv_distributed_002                0             0

# %%
len(generation_wind)
# Out:
# 159

# %%
rens = []
for index, row in generation_wind.iterrows():
    lz = row['gen_load_zone'].split('-')[0]
    gen = row['gen_tech'].split('_')[0]
    proj = 'proj1'
    lz = "{:d}".format(int(lz))
    file = [s for s in file_cluster if lz in s and gen in s and proj in s][0]
    tmp = pd.read_csv(file, index_col=0, parse_dates=True)
    tmp.loc[:, 'project_name'] = index
    if gen == 'solarpv':
        tmp.loc[:, 'capacity_factor'] = tmp.loc[:,'generation']/1000
    else:
        tmp.loc[:, 'capacity_factor'] = tmp.loc[:,'generation']/2000
    tmp.loc[:, 'time'] = tmp.index.strftime('%m-%d %H:%M:%S')
    tmp.loc[tmp.index.minute == 30, 'time'] = (tmp.index - pd.Timedelta(minutes=30) ).strftime('%m-%d %H:%M:%S')
    tmp.index.names = ['datetime']
    rens.append(tmp)

rens = pd.concat(rens)

# %%
parent_path = os.path.dirname(os.path.dirname('..'))
file_path = os.path.join('../', 'data/clean/SWITCH/')
filename = 'ren-all2.csv'
ren_cap_data = pd.read_csv(os.path.join(file_path, filename), index_col=0,
                           parse_dates=['datetime'])
ren_cap_data['project_name'] = ren_cap_data['GENERATION_PROJECT']
print (len(ren_cap_data.project_name.unique()))
ren_cap_data.info()
# Out:
# 218
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1909992 entries, 2002-12-31 23:00:00 to 2015-01-01 05:30:00
# Data columns (total 5 columns):
# generation            float64
# capacity_factor       float64
# GENERATION_PROJECT    object
# time                  object
# project_name          object
# dtypes: float64(2), object(3)
# memory usage: 87.4+ MB

# %%
ren_cap_data = ren_cap_data.loc[~ren_cap_data.project_name.isnull()]
print (len(ren_cap_data.project_name.unique()))
# Out:
# 218

# %%
merged = pd.concat([ren_cap_data, rens])

# %%
assert len(merged.project_name.unique()) == (len(rens.project_name.unique()) + len(ren_cap_data.GENERATION_PROJECT.unique()))

# %%
parent_path = os.path.dirname(os.path.dirname('..'))
file_path = os.path.join('../', 'data/clean/SWITCH/')
filename = 'ren-all5.csv'
merged.to_csv(os.path.join(file_path, filename))

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4231392 entries, 2002-12-31 23:00:00 to 2015-01-01 05:00:00
# Data columns (total 6 columns):
# GENERATION_PROJECT    object
# capacity_factor       float64
# generation            float64
# hour                  float64
# project_name          object
# time                  object
# dtypes: float64(3), object(3)
# memory usage: 226.0+ MB

# %%
ren_cap_data.project_name.unique()
# Out:
# array(['abr-99', 'aguascalientes_sur_1', 'alten_6',
#        'alten_aguascalientes_1_5', 'andalucia_ii', 'at_solar_i_iv',
#        'autoabastecimiento_renovable', 'bii_nee_stipa_energia_eolica',
#        'bluemex_power', 'calpulalpan', 'ce_018', 'ce_019', 'ce_020',
#        'ce_021', 'ce_022', 'ce_027', 'ce_028', 'ce_029', 'ce_033',
#        'ce_034', 'ce_035', 'compañia_eolica_de_tamaulipas',
#        'compañia_eoloelectrica_de_ciudad_victoria', 'conejo', 'coppel',
#        'cs_041', 'cs_047', 'cs_048', 'cs_049', 'cs_052', 'cs_053',
#        'cs_054', 'cs_055', 'cs_056', 'cs_057', 'cs_058',
#        'desarrollos_eolicos_mexicanos_de_oaxaca_1',
#        'desarrollos_eolicos_mexicanos_de_oaxaca_2,_piedra_larga_fase_2',
#        'dolores', 'dominica_energia_limpia', 'el_mayo',
#        'electrica_del_valle_de_mexico', 'energia_limpia_de_amistad_2',
#        'energia_limpia_de_amistad_3', 'energia_limpia_de_amistad_4',
#        'energia_limpia_de_palo_alto', 'energia_sierra_juarez',
#        'energia_sonora_ppe', 'energias_ambientales_de_oaxaca,_oaxaca_i',
#        'energias_renovables_la_mata,_la_mata_(sureste_i_fase_ii)',
#        'energias_renovables_venta_iii,_la_venta_iii',
#        'eoliatec_del_istmo', 'eoliatec_del_pacifico', 'eolica_de_arriaga',
#        'eolica_de_coahuila', 'eolica_dos_arbolitos', 'eolica_el_retiro',
#        'eolica_los_altos', 'eolica_santa_catarina', 'eolica_tres_mesas',
#        'eolica_zopiloapan', 'eurus,_juchitan_de_zaragoza_oaxaca',
#        'fuerza_eolica_del_istmo', 'fuerza_y_energia_bii_hioxo',
#        'generadora_solar_apaseo', 'horus_ag',
#        'instituto_de_investigaciones_electricas', 'iusasol_1',
#        'iusasol_base', 'la_venta_i-ii', 'los_santos_solar_i',
#        'mexsolar_i_ii', 'municipio_de_mexicali', 'oomapas_nogales',
#        'orejana', 'pachamama', 'parque_eolico_el_cortijo',
#        'parque_solar_calera', 'parques_ecologicos_de_mexico',
#        'pe_ingenio', 'pier_ii_quecholac_felipe_angeles', 'plamex',
#        'planta_solar_fv_bacabachi_i', 'potosi_solar', 'productora_yoreme',
#        'puerto_viejo_(guerrero_negro)', 'rumorosa',
#        'san_miguel_allende_5', 'santa_maria',
#        'servicios_comerciales_de_energia', 'sta._rosalia_(tres_virgenes)',
#        'stipa_nayaa', 'tai_durango_cinco', 'tai_durango_cuatro',
#        'tai_durango_dos', 'tai_durango_tres', 'tai_durango_uno',
#        'tastiota', 'tepezala_ii', 'tm4_v150_4.0_105_v1', 'torreon_hq1co',
#        'trompezon', 'ventika', 'ventika_ii', 'vientos_del_altiplano',
#        'villa_ahumada', 'xoxocotla', "yuumil'iik",
#        'ce_oaxaca_cuatro,_oaxaca_iv', 'ce_oaxaca_dos,_oaxaca_ii',
#        'ce_oaxaca_tres,_oaxaca_iii', 'cerro_prieto', 'wind_lz1-proj1',
#        'wind_lz10-proj1', 'wind_lz11-proj1', 'wind_lz12-proj1',
#        'wind_lz13-proj1', 'wind_lz14-proj1', 'wind_lz15-proj1',
#        'wind_lz16-proj1', 'wind_lz17-proj1', 'wind_lz18-proj1',
#        'wind_lz19-proj1', 'wind_lz2-proj1', 'wind_lz20-proj1',
#        'wind_lz21-proj1', 'wind_lz22-proj1', 'wind_lz23-proj1',
#        'wind_lz24-proj1', 'wind_lz25-proj1', 'wind_lz26-proj1',
#        'wind_lz27-proj1', 'wind_lz28-proj1', 'wind_lz29-proj1',
#        'wind_lz3-proj1', 'wind_lz30-proj1', 'wind_lz31-proj1',
#        'wind_lz32-proj1', 'wind_lz33-proj1', 'wind_lz34-proj1',
#        'wind_lz35-proj1', 'wind_lz36-proj1', 'wind_lz37-proj1',
#        'wind_lz38-proj1', 'wind_lz39-proj1', 'wind_lz4-proj1',
#        'wind_lz40-proj1', 'wind_lz41-proj1', 'wind_lz42-proj1',
#        'wind_lz43-proj1', 'wind_lz44-proj1', 'wind_lz45-proj1',
#        'wind_lz46-proj1', 'wind_lz47-proj1', 'wind_lz48-proj1',
#        'wind_lz49-proj1', 'wind_lz5-proj1', 'wind_lz50-proj1',
#        'wind_lz51-proj1', 'wind_lz52-proj1', 'wind_lz53-proj1',
#        'wind_lz6-proj1', 'wind_lz7-proj1', 'wind_lz8-proj1',
#        'wind_lz9-proj1', 'solar_lz1-proj1', 'solar_lz10-proj1',
#        'solar_lz11-proj1', 'solar_lz12-proj1', 'solar_lz13-proj1',
#        'solar_lz14-proj1', 'solar_lz15-proj1', 'solar_lz16-proj1',
#        'solar_lz17-proj1', 'solar_lz18-proj1', 'solar_lz19-proj1',
#        'solar_lz2-proj1', 'solar_lz20-proj1', 'solar_lz21-proj1',
#        'solar_lz22-proj1', 'solar_lz23-proj1', 'solar_lz24-proj1',
#        'solar_lz25-proj1', 'solar_lz26-proj1', 'solar_lz27-proj1',
#        'solar_lz28-proj1', 'solar_lz29-proj1', 'solar_lz3-proj1',
#        'solar_lz30-proj1', 'solar_lz31-proj1', 'solar_lz32-proj1',
#        'solar_lz33-proj1', 'solar_lz34-proj1', 'solar_lz35-proj1',
#        'solar_lz36-proj1', 'solar_lz37-proj1', 'solar_lz38-proj1',
#        'solar_lz39-proj1', 'solar_lz4-proj1', 'solar_lz40-proj1',
#        'solar_lz41-proj1', 'solar_lz42-proj1', 'solar_lz43-proj1',
#        'solar_lz44-proj1', 'solar_lz45-proj1', 'solar_lz46-proj1',
#        'solar_lz47-proj1', 'solar_lz48-proj1', 'solar_lz49-proj1',
#        'solar_lz5-proj1', 'solar_lz50-proj1', 'solar_lz51-proj1',
#        'solar_lz52-proj1', 'solar_lz53-proj1', 'solar_lz6-proj1',
#        'solar_lz7-proj1', 'solar_lz8-proj1', 'solar_lz9-proj1', nan],
#       dtype=object)
