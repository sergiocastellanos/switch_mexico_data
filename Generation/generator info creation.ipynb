# %%
import pandas  as pd
import numpy as np
df1=pd.read_csv('data/chile_generator_info.tab',sep='\t')
df2=pd.read_csv('../Main Tabs/generator_energy_sources.tab',sep='\t',index_col=0)
df3=pd.read_csv('data/PowerPlants.csv')
df4=pd.read_csv('data/TechCostsSergio.tab',sep="\t",index_col=0)
df5=pd.read_csv('data/generator_max_age.tab',sep="\t",index_col=0)
df5=df5.fillna(value=0)
df3=df3.fillna(value=0)

# %%
#using PIIRCE's information to estimate the full load heat rate for every generation technology 
#using a weighted average. For more information, check the report.
for i in df3['gen_tech'].unique():
    dfa=df3[df3['gen_tech']==i]
    t=dfa['capacity_mw'].sum()
    dfa['weight']=dfa['capacity_mw']/t
    df2.loc[i,'g_full_load_heat_rate']=((dfa['weight']*dfa['full_load_heat_rate']).sum())
# Out:
# C:\Users\Aldo\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in df2.index.tolist():
    print i
    df2.loc[i,'g_variable_o_m']=df4[df4['investment_period']==2020]['g_variable_o_m'].to_dict()[i]
# Out:
# carboelectric_coal
# combined_cycle_natural_gas
# internal_combustion_fuel_oil
# internal_combustion_diesel
# internal_combustion_natural_gas
# wind
# geothermal
# hydroelectric
# nuclear_uranium
# solar
# thermal_fuel_oil
# thermal_natural_gas
# thermal_diesel
# thermosolar
# gas_turbine_diesel
# gas_turbine_natural_gas
# bioenergy_fuel_oil
# bioenergy_natural_gas
# bioenergy_diesel
# cogen_fuel_oil
# cogen_natural_gas
# cogen_diesel
# fluidized_bed_coal
# import_natural_gas
# regen_brakes

# %%
df2['g_min_build_capacity']=0
for i in df2.index.tolist():
    dfa=df3[df3['gen_tech']==i]
    t=dfa['capacity_mw'].sum()
    dfa['weight']=dfa['capacity_mw']/t
    df2.loc[i,'g_full_load_heat_rate']=((dfa['weight']*dfa['full_load_heat_rate']).sum())
    df2.loc[i,'g_variable_o_m']=df4[df4['investment_period']==2020]['g_variable_o_m'].to_dict()[i]
    df2.loc[i,'g_scheduled_outage_rate']=df3[df3['gen_tech']==i]['scheduled_outage_rate'].tolist()[0]
    df2.loc[i,'g_forced_outage_rate']=df3[df3['gen_tech']==i]['scheduled_outage_rate'].tolist()[0]
    if i=='nuclear_uranium':
        df2.loc[i,'g_min_build_capacity']=sorted(df3[df3['gen_tech']=='nuclear_uranium']['capacity_mw'].tolist())[1]
    df2.loc[i,'g_max_age']=df5.loc[i,'g_max_age']
df2
# Out:
# C:\Users\Aldo\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                 energy_source  g_full_load_heat_rate  \
# generation_technology
# carboelectric_coal                      coal                8.953704
# combined_cycle_natural_gas        natural_gas               6.831767
# internal_combustion_fuel_oil        fuel_oil                9.683046
# internal_combustion_diesel             diesel               9.408501
# internal_combustion_natural_gas   natural_gas               9.143437
# wind                                     wind               0.000000
# geothermal                           geosteam               0.000000
# hydroelectric                           water               0.000000
# nuclear_uranium                      uranium                9.780029
# solar                                   solar               0.000000
# thermal_fuel_oil                    fuel_oil               10.238679
# thermal_natural_gas               natural_gas              15.085310
# thermal_diesel                         diesel              11.294083
# thermosolar                             solar               0.000000
# gas_turbine_diesel                     diesel              16.879779
# gas_turbine_natural_gas           natural_gas              14.214213
# bioenergy_fuel_oil                  fuel_oil               83.790066
# bioenergy_natural_gas             natural_gas               8.837299
# bioenergy_diesel                       diesel             133.581328
# cogen_fuel_oil                      fuel_oil                9.099526
# cogen_natural_gas                 natural_gas               6.758715
# cogen_diesel                           diesel               9.467692
# fluidized_bed_coal                      coal                9.383886
# import_natural_gas                natural_gas               9.099526
# regen_brakes                          kinetic               6.824645
#
#                                  g_variable_o_m  g_min_build_capacity  \
# generation_technology
# carboelectric_coal                       3.7820                  0.00
# combined_cycle_natural_gas               3.0500                  0.00
# internal_combustion_fuel_oil             6.6300                  0.00
# internal_combustion_diesel               6.6300                  0.00
# internal_combustion_natural_gas          6.6300                  0.00
# wind                                     0.0000                  0.00
# geothermal                               0.0600                  0.00
# hydroelectric                            0.0000                  0.00
# nuclear_uranium                          2.2500               1312.69
# solar                                    0.0000                  0.00
# thermal_fuel_oil                         2.6880                  0.00
# thermal_natural_gas                      2.6880                  0.00
# thermal_diesel                           2.6880                  0.00
# thermosolar                              0.0000                  0.00
# gas_turbine_diesel                       3.4320                  0.00
# gas_turbine_natural_gas                  3.4320                  0.00
# bioenergy_fuel_oil                       3.9400                  0.00
# bioenergy_natural_gas                    4.3700                  0.00
# bioenergy_diesel                         3.9400                  0.00
# cogen_fuel_oil                           3.0846                  0.00
# cogen_natural_gas                        3.0800                  0.00
# cogen_diesel                             3.9900                  0.00
# fluidized_bed_coal                       2.4600                  0.00
# import_natural_gas                       0.0000                  0.00
# regen_brakes                             4.4300                  0.00
#
#                                  g_scheduled_outage_rate  \
# generation_technology
# carboelectric_coal                                 11.71
# combined_cycle_natural_gas                          6.96
# internal_combustion_fuel_oil                       11.23
# internal_combustion_diesel                         11.23
# internal_combustion_natural_gas                    11.23
# wind                                                0.00
# geothermal                                          5.12
# hydroelectric                                       3.00
# nuclear_uranium                                    10.68
# solar                                               0.00
# thermal_fuel_oil                                   11.44
# thermal_natural_gas                                11.44
# thermal_diesel                                     11.44
# thermosolar                                         0.00
# gas_turbine_diesel                                  9.22
# gas_turbine_natural_gas                             9.22
# bioenergy_fuel_oil                                 11.44
# bioenergy_natural_gas                              11.23
# bioenergy_diesel                                   11.44
# cogen_fuel_oil                                     11.44
# cogen_natural_gas                                  11.23
# cogen_diesel                                       11.44
# fluidized_bed_coal                                 11.71
# import_natural_gas                                  9.22
# regen_brakes                                        6.96
#
#                                  g_forced_outage_rate  g_max_age
# generation_technology
# carboelectric_coal                              11.71       20.0
# combined_cycle_natural_gas                       6.96       30.0
# internal_combustion_fuel_oil                    11.23       20.0
# internal_combustion_diesel                      11.23       20.0
# internal_combustion_natural_gas                 11.23       30.0
# wind                                             0.00       25.0
# geothermal                                       5.12       30.0
# hydroelectric                                    3.00       50.0
# nuclear_uranium                                 10.68       60.0
# solar                                            0.00       25.0
# thermal_fuel_oil                                11.44       30.0
# thermal_natural_gas                             11.44       30.0
# thermal_diesel                                  11.44       30.0
# thermosolar                                      0.00       20.0
# gas_turbine_diesel                               9.22       30.0
# gas_turbine_natural_gas                          9.22       30.0
# bioenergy_fuel_oil                              11.44       20.0
# bioenergy_natural_gas                           11.23       20.0
# bioenergy_diesel                                11.44       20.0
# cogen_fuel_oil                                  11.44       30.0
# cogen_natural_gas                               11.23       30.0
# cogen_diesel                                    11.44       30.0
# fluidized_bed_coal                              11.71       20.0
# import_natural_gas                               9.22       20.0
# regen_brakes                                     6.96        0.0

# %%
#optional parameters that will be ignored
ignored=["g_unit_size","g_ccs_capture_efficiency","g_ccs_energy_load","g_storage_efficiency","g_store_to_release_ratio"]
for i in ignored:
    df2[i]=0
#boolean parameters that will be estimated
boole=["g_is_variable","g_is_baseload","g_is_flexible_baseload","g_is_cogen","g_competes_for_space"]

# %%
df2.to_csv('data/generator_info_trial.tab',sep="\t")
