# %%
import pandas as pd 
import numpy as np
df1=pd.read_csv("data/PowerPlants.csv",header=0,index_col=0)
df2=pd.read_csv("data/TechCosts.csv",header=0,index_col=0)
def nearest_value(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
def lis(x):
    if isinstance(x,list): return np.asarray(x)
    else: return np.asarray([x])
#selecting only the generating plants of interest. See report for more details.
df1=df1.loc[df1['being_built'].isin([a for a in list(set(df1['being_built'].tolist())) if a  not in ['generic_project','optimization']])]

# %%
for i in df1.index.tolist():
    #setting auxiliary dataframe for plant gen_tech info
    df3=df2.loc[df1.loc[i,'gen_tech'],:]
    #iterating over the costs
    print i
    for name in ['fixed_o_m','variable_o_m','overnight_cost']:
        print name
        #selecting the costs according to the capacity and technology of the plant
        #try and except due to error with length of dataframe
        print df2.loc[df1.loc[i,'gen_tech'],'capacity_mw']
        try: a=df3.loc[df3['capacity_mw']==nearest_value(lis(df2.loc[df1.loc[i,'gen_tech'],'capacity_mw'].tolist()),df1.loc[i,'capacity_limit_mw'].astype('float'))]
        except KeyError: a=df3
        df1.loc[i,name]=float(a[name])
# Out:
# cerro_prieto_i_u5
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cerro_prieto_ii_central
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cerro_prieto_iii_central
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cerro_prieto_iv_central
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cerro_prieto_fotovoltaica
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cipres_tg
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# mexicali
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# mexicali_tg_1
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# mexicali_tg_2
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# mexicali_tg_3
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# presidente_juarez_rosarito
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# presidente_juarez_rosarito5_tc
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# presidente_juarez_rosarito6_tc
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# tijuana_1_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# tijuana_2_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# tijuana_3_tg_150mw
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# tijuana_tg_central
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# baja_california_sur_i
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# ciudad_constitucion
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# guerrero_negro
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# guerrero_negro_ii
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# la_paz_tg1
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# la_paz_tg2
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# los_cabos_cfe_25000
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# los_cabos_cfe_30000
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# los_cabos_1_tg
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# los_cabos_2_tg
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# los_cabos_3_tg
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# punta_prieta_ii_u1
# fixed_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# punta_prieta_ii_u2
# fixed_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# punta_prieta_ii_u3
# fixed_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_diesel    350.0
# thermal_diesel    160.0
# thermal_diesel     80.0
# Name: capacity_mw, dtype: float64
# san_carlos_u1
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# san_carlos_u2
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# san_carlos_u3
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# santa_rosalia_u1_u2
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# santa_rosalia_u3_ci
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# santa_rosalia_u4_ci
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# santa_rosalia_u5_ci
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# tres_virgcos_central
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# u_movil
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# chicoasen
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# aragon
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# atenco_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# coapa
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# coyotepec
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# cuautitlan_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# ecatepec_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# infiernillo
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# iztapalapa_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# malpaso
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# magdalena
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# aguamilpa_solidaridad
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# nonoalco_lyfc_u1
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# nonoalco_lyfc_u2
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# nonoalco_lyfc_u3
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# angostura
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# remedios_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# santa_cruz
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# el_cajon
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# tula
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# tula_tc_u1
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# tula_tc_u2
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# tula_tc_u3
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# tula_tc_u4
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# tula_tc_u5
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# valle_de_mexico
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# valle_de_mexico_tc_u1
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# valle_de_mexico_tc_u2
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# valle_de_mexico_tc_u3
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# vallejo_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# victoria_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# villa_de_las_flores_lyfc
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# la_yesca
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# guerrero_negro_ii_tgmovil
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# guerrero_negro_eolica
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# sta_rosalia
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# u_movil_cfe-ume
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# u_movil_de_emergencia_ume-18
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# u_movil_de_emergencia_ume-19
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# u_movil_de_emergencia_ume-20
# fixed_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_fuel_oil    44.0
# internal_combustion_fuel_oil     3.6
# Name: capacity_mw, dtype: float64
# vizcaino
# fixed_o_m
# 44.0
# variable_o_m
# 44.0
# overnight_cost
# 44.0
# caracol
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# chavez_u1
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# chavez_u2
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# chihuahua_ii
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# huites
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# francisco_villa_u4
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# francisco_villa_u5
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# gomez_palacio
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# industrial_juarez
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# la_laguna_ii
# fixed_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# variable_o_m
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# overnight_cost
# combined_cycle_natural_gas     114.4
# combined_cycle_natural_gas     285.7
# combined_cycle_natural_gas     575.1
# combined_cycle_natural_gas     864.6
# combined_cycle_natural_gas     408.5
# combined_cycle_natural_gas     823.8
# combined_cycle_natural_gas     413.4
# combined_cycle_natural_gas     833.6
# combined_cycle_natural_gas    4609.0
# combined_cycle_natural_gas     929.7
# Name: capacity_mw, dtype: float64
# la_laguna_u1_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# la_laguna_u2_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# la_laguna_u3_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# la_laguna_u4_tg
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# ...
# Name: capacity_mw, dtype: float64
# variable_o_m
# internal_combustion_natural_gas    44.0
# internal_combustion_natural_gas     3.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# internal_combustion_natural_gas    44.0
# internal_combustion_natural_gas     3.6
# Name: capacity_mw, dtype: float64
# ce_aut_74
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_45
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_34
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_46
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_75
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_47
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_04
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_48
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_07
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_49
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_36
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_37
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_39
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_61
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_25
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_72
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_58
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_13
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_71
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_17
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_53
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_54
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_55
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_40
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_41
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_56
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_33
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_73
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_aut_44
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# energia_renovable_de_la_peninsula
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# pe_el_cortijo
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_cfe_02
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_cfe_03
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_gen_02
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_gen_01
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_07
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_01
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_08
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_09
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_10
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_02
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_05
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_otr_06
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# parque_eolico_chabacal
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# parque_eolico_tizimin
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_pie_01
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_pie_02
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_pie_03
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_pp_01
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# ce_pp_03
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# parque_eolico_chabacal_ii
# fixed_o_m
# 2.0
# variable_o_m
# 2.0
# overnight_cost
# 2.0
# cg_cfe_04
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cg_cfe_05
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cg_cfe_02
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# cg_cfe_03
# fixed_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# variable_o_m
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# overnight_cost
# geothermal    27.0
# geothermal    26.6
# Name: capacity_mw, dtype: float64
# ch_aut_28
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_aut_27
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_cfe_01
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_cfe_03
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_pp_09
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_pp_13
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_pp_11
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# ch_pp_12
# fixed_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# variable_o_m
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# overnight_cost
# hydroelectric     375.0
# hydroelectric    8102.0
# hydroelectric      35.5
# Name: capacity_mw, dtype: float64
# cn_cfe_01
# fixed_o_m
# nuclear_uranium    1200.0
# nuclear_uranium    1400.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# nuclear_uranium    1200.0
# nuclear_uranium    1400.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# nuclear_uranium    1200.0
# nuclear_uranium    1400.0
# Name: capacity_mw, dtype: float64
# cs_aut_01
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_aut_10
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_aut_19
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_cfe_02
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_gen_01
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_01
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_11
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_12
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_02
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_03
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_06
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_17
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_04
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_otr_05
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# aguascalientes_potencia_1
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# parque_solar_don_jose
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# parque_solar_villanueva_3
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# parque_solar_villanueva
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# concunul
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# las_viborilas
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# san_ignacio
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# kambul
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# guajiro_2
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# ticul_1
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_05
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_06
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_08
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_09
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_10
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_12
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_55
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_01
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_13
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_40
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_14
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_56
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_41
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_42
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_43
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_16
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_44
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_45
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_46
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_17
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_47
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_48
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_18
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_21
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_49
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_50
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_51
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_52
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_24
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_113
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_53
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_114
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_25
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_02
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_03
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_26
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_28
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_04
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# cs_pp_54
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# sol_de_insurgentes
# fixed_o_m
# 60.0
# variable_o_m
# 60.0
# overnight_cost
# 60.0
# ctc_cfe_02
# fixed_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_fuel_oil    350.0
# thermal_fuel_oil    160.0
# thermal_fuel_oil     80.0
# Name: capacity_mw, dtype: float64
# ctc_exp_01
# fixed_o_m
# thermal_natural_gas    350.0
# thermal_natural_gas    160.0
# thermal_natural_gas     80.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# thermal_natural_gas    350.0
# thermal_natural_gas    160.0
# thermal_natural_gas     80.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# thermal_natural_gas    350.0
# thermal_natural_gas    160.0
# thermal_natural_gas     80.0
# Name: capacity_mw, dtype: float64
# cs_cfe_01
# fixed_o_m
# nan
# variable_o_m
# nan
# overnight_cost
# nan
# ctg_aut_06
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# ctg_cog_07
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# ctg_pp_01
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# ctg_pp_02
# fixed_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# variable_o_m
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64
# overnight_cost
# gas_turbine_natural_gas     44.7
# gas_turbine_natural_gas    103.5
# gas_turbine_natural_gas     88.8
# gas_turbine_natural_gas    186.5
# gas_turbine_natural_gas    275.6
# gas_turbine_natural_gas    280.4
# gas_turbine_natural_gas    319.0
# Name: capacity_mw, dtype: float64

# %%
#export data
df1.to_csv('data/GenerationPlantsWithCosts.csv')
