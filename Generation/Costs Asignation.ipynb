# %%
import pandas as pd 
import numpy as np
df1=pd.read_csv("data/GenerationPlants.csv",header=0,index_col=0)
df2=pd.read_csv("data/TechCosts.csv",header=0,index_col=0)
def nearest_value(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
def lista(x):
    if isinstance(x,list): return np.asarray(x)
    else: return np.asarray([x])
#selecting only the generating plants of interest. See report for more details.
df1=df1.loc[df1['being_built'].isin(['firm_project','rehabilitation_modernization','operational'])]
# Out:
#                                                     gen_tech  \
# project_name
# cerro_prieto_i_u5                                 geothermal
# cerro_prieto_ii_central                           geothermal
# cerro_prieto_iii_central                          geothermal
# cerro_prieto_iv_central                           geothermal
# cerro_prieto_fotovoltaica                              solar
# cipres_tg                                 gas_turbine_diesel
# mexicali                          combined_cycle_natural_gas
# mexicali_tg_1                             gas_turbine_diesel
# mexicali_tg_2                             gas_turbine_diesel
# mexicali_tg_3                             gas_turbine_diesel
# presidente_juarez_rosarito        combined_cycle_natural_gas
# presidente_juarez_rosarito5_tc              thermal_fuel_oil
# presidente_juarez_rosarito6_tc              thermal_fuel_oil
# tijuana_1_tg                         gas_turbine_natural_gas
# tijuana_2_tg                         gas_turbine_natural_gas
# tijuana_3_tg_150mw                   gas_turbine_natural_gas
# tijuana_tg_central                   gas_turbine_natural_gas
# baja_california_sur_i           internal_combustion_fuel_oil
# ciudad_constitucion                       gas_turbine_diesel
# guerrero_negro                            gas_turbine_diesel
# guerrero_negro_ii               internal_combustion_fuel_oil
# la_paz_tg1                                gas_turbine_diesel
# la_paz_tg2                                gas_turbine_diesel
# los_cabos_cfe_25000                       gas_turbine_diesel
# los_cabos_cfe_30000                       gas_turbine_diesel
# los_cabos_1_tg                            gas_turbine_diesel
# los_cabos_2_tg                            gas_turbine_diesel
# los_cabos_3_tg                            gas_turbine_diesel
# punta_prieta_ii_u1                            thermal_diesel
# punta_prieta_ii_u2                            thermal_diesel
# ...                                                      ...
# cs_pp_44                                               solar
# cs_pp_45                                               solar
# cs_pp_46                                               solar
# cs_pp_17                                               solar
# cs_pp_47                                               solar
# cs_pp_48                                               solar
# cs_pp_18                                               solar
# cs_pp_21                                               solar
# cs_pp_49                                               solar
# cs_pp_50                                               solar
# cs_pp_51                                               solar
# cs_pp_52                                               solar
# cs_pp_24                                               solar
# cs_pp_113                                              solar
# cs_pp_53                                               solar
# cs_pp_114                                              solar
# cs_pp_25                                               solar
# cs_pp_02                                               solar
# cs_pp_03                                               solar
# cs_pp_26                                               solar
# cs_pp_28                                               solar
# cs_pp_04                                               solar
# cs_pp_54                                               solar
# ctc_cfe_02                                  thermal_fuel_oil
# ctc_exp_01                               thermal_natural_gas
# cs_cfe_01                                         termosolar
# ctg_aut_06                           gas_turbine_natural_gas
# ctg_cog_07                           gas_turbine_natural_gas
# ctg_pp_01                            gas_turbine_natural_gas
# ctg_pp_02                            gas_turbine_natural_gas
#
#                                                     load_zone  \
# project_name
# cerro_prieto_i_u5                          08-baja_california
# cerro_prieto_ii_central                    08-baja_california
# cerro_prieto_iii_central                   08-baja_california
# cerro_prieto_iv_central                    08-baja_california
# cerro_prieto_fotovoltaica                  08-baja_california
# cipres_tg                                  08-baja_california
# mexicali                                   08-baja_california
# mexicali_tg_1                              08-baja_california
# mexicali_tg_2                              08-baja_california
# mexicali_tg_3                              08-baja_california
# presidente_juarez_rosarito                 08-baja_california
# presidente_juarez_rosarito5_tc             08-baja_california
# presidente_juarez_rosarito6_tc             08-baja_california
# tijuana_1_tg                               08-baja_california
# tijuana_2_tg                               08-baja_california
# tijuana_3_tg_150mw                         08-baja_california
# tijuana_tg_central                         08-baja_california
# baja_california_sur_i           09-baja_california_sur-la_paz
# ciudad_constitucion             09-baja_california_sur-la_paz
# guerrero_negro                  10-baja_california_sur-mulege
# guerrero_negro_ii               10-baja_california_sur-mulege
# la_paz_tg1                      09-baja_california_sur-la_paz
# la_paz_tg2                      09-baja_california_sur-la_paz
# los_cabos_cfe_25000             09-baja_california_sur-la_paz
# los_cabos_cfe_30000             09-baja_california_sur-la_paz
# los_cabos_1_tg                  09-baja_california_sur-la_paz
# los_cabos_2_tg                  09-baja_california_sur-la_paz
# los_cabos_3_tg                  09-baja_california_sur-la_paz
# punta_prieta_ii_u1              09-baja_california_sur-la_paz
# punta_prieta_ii_u2              09-baja_california_sur-la_paz
# ...                                                       ...
# cs_pp_44                                        03-occidental
# cs_pp_45                                        03-occidental
# cs_pp_46                                          04-noroeste
# cs_pp_17                        09-baja_california_sur-la_paz
# cs_pp_47                                        03-occidental
# cs_pp_48                                        03-occidental
# cs_pp_18                        09-baja_california_sur-la_paz
# cs_pp_21                                          04-noroeste
# cs_pp_49                                        03-occidental
# cs_pp_50                                             05-norte
# cs_pp_51                                          04-noroeste
# cs_pp_52                                           06-noreste
# cs_pp_24                                          04-noroeste
# cs_pp_113                                         04-noroeste
# cs_pp_53                                        03-occidental
# cs_pp_114                                            05-norte
# cs_pp_25                                             05-norte
# cs_pp_02                                             05-norte
# cs_pp_03                                             05-norte
# cs_pp_26                                             05-norte
# cs_pp_28                                             05-norte
# cs_pp_04                                             05-norte
# cs_pp_54                                             05-norte
# ctc_cfe_02                                         06-noreste
# ctc_exp_01                                         06-noreste
# cs_cfe_01                                         04-noroeste
# ctg_aut_06                                         01-central
# ctg_cog_07                                        02-oriental
# ctg_pp_01                                         04-noroeste
# ctg_pp_02                                         04-noroeste
#
#                                 full_load_heat_rate  connect_cost_per_mw  \
# project_name
# cerro_prieto_i_u5                               0.0                  0.0
# cerro_prieto_ii_central                         0.0                  0.0
# cerro_prieto_iii_central                        0.0                  0.0
# cerro_prieto_iv_central                         0.0                  0.0
# cerro_prieto_fotovoltaica                       0.0                  0.0
# cipres_tg                                      18.2                  0.0
# mexicali                                        7.9                  0.0
# mexicali_tg_1                                  22.3                  0.0
# mexicali_tg_2                                  22.3                  0.0
# mexicali_tg_3                                  22.3                  0.0
# presidente_juarez_rosarito                     11.0                  0.0
# presidente_juarez_rosarito5_tc                 11.0                  0.0
# presidente_juarez_rosarito6_tc                 11.0                  0.0
# tijuana_1_tg                                   10.8                  0.0
# tijuana_2_tg                                   10.8                  0.0
# tijuana_3_tg_150mw                             10.8                  0.0
# tijuana_tg_central                             10.8                  0.0
# baja_california_sur_i                          10.3                  0.0
# ciudad_constitucion                            19.2                  0.0
# guerrero_negro                                 27.8                  0.0
# guerrero_negro_ii                              10.3                  0.0
# la_paz_tg1                                     18.2                  0.0
# la_paz_tg2                                     18.2                  0.0
# los_cabos_cfe_25000                             9.6                  0.0
# los_cabos_cfe_30000                            11.4                  0.0
# los_cabos_1_tg                                 18.1                  0.0
# los_cabos_2_tg                                 18.1                  0.0
# los_cabos_3_tg                                 18.1                  0.0
# punta_prieta_ii_u1                             12.0                  0.0
# punta_prieta_ii_u2                             12.0                  0.0
# ...                                             ...                  ...
# cs_pp_44                                        0.0                  0.0
# cs_pp_45                                        0.0                  0.0
# cs_pp_46                                        0.0                  0.0
# cs_pp_17                                        0.0                  0.0
# cs_pp_47                                        0.0                  0.0
# cs_pp_48                                        0.0                  0.0
# cs_pp_18                                        0.0                  0.0
# cs_pp_21                                        0.0                  0.0
# cs_pp_49                                        0.0                  0.0
# cs_pp_50                                        0.0                  0.0
# cs_pp_51                                        0.0                  0.0
# cs_pp_52                                        0.0                  0.0
# cs_pp_24                                        0.0                  0.0
# cs_pp_113                                       0.0                  0.0
# cs_pp_53                                        0.0                  0.0
# cs_pp_114                                       0.0                  0.0
# cs_pp_25                                        0.0                  0.0
# cs_pp_02                                        0.0                  0.0
# cs_pp_03                                        0.0                  0.0
# cs_pp_26                                        0.0                  0.0
# cs_pp_28                                        0.0                  0.0
# cs_pp_04                                        0.0                  0.0
# cs_pp_54                                        0.0                  0.0
# ctc_cfe_02                                     10.3                  0.0
# ctc_exp_01                                      9.3                  0.0
# cs_cfe_01                                       0.0                  0.0
# ctg_aut_06                                     11.8                  0.0
# ctg_cog_07                                      9.6                  0.0
# ctg_pp_01                                       9.6                  0.0
# ctg_pp_02                                       9.6                  0.0
#
#                                 variable_o_m  forced_outage_rate  \
# project_name
# cerro_prieto_i_u5                        NaN                 NaN
# cerro_prieto_ii_central                  NaN                 NaN
# cerro_prieto_iii_central                 NaN                 NaN
# cerro_prieto_iv_central                  NaN                 NaN
# cerro_prieto_fotovoltaica                NaN                 NaN
# cipres_tg                                NaN                 NaN
# mexicali                                 NaN                 NaN
# mexicali_tg_1                            NaN                 NaN
# mexicali_tg_2                            NaN                 NaN
# mexicali_tg_3                            NaN                 NaN
# presidente_juarez_rosarito               NaN                 NaN
# presidente_juarez_rosarito5_tc           NaN                 NaN
# presidente_juarez_rosarito6_tc           NaN                 NaN
# tijuana_1_tg                             NaN                 NaN
# tijuana_2_tg                             NaN                 NaN
# tijuana_3_tg_150mw                       NaN                 NaN
# tijuana_tg_central                       NaN                 NaN
# baja_california_sur_i                    NaN                 NaN
# ciudad_constitucion                      NaN                 NaN
# guerrero_negro                           NaN                 NaN
# guerrero_negro_ii                        NaN                 NaN
# la_paz_tg1                               NaN                 NaN
# la_paz_tg2                               NaN                 NaN
# los_cabos_cfe_25000                      NaN                 NaN
# los_cabos_cfe_30000                      NaN                 NaN
# los_cabos_1_tg                           NaN                 NaN
# los_cabos_2_tg                           NaN                 NaN
# los_cabos_3_tg                           NaN                 NaN
# punta_prieta_ii_u1                       NaN                 NaN
# punta_prieta_ii_u2                       NaN                 NaN
# ...                                      ...                 ...
# cs_pp_44                                 NaN                 NaN
# cs_pp_45                                 NaN                 NaN
# cs_pp_46                                 NaN                 NaN
# cs_pp_17                                 NaN                 NaN
# cs_pp_47                                 NaN                 NaN
# cs_pp_48                                 NaN                 NaN
# cs_pp_18                                 NaN                 NaN
# cs_pp_21                                 NaN                 NaN
# cs_pp_49                                 NaN                 NaN
# cs_pp_50                                 NaN                 NaN
# cs_pp_51                                 NaN                 NaN
# cs_pp_52                                 NaN                 NaN
# cs_pp_24                                 NaN                 NaN
# cs_pp_113                                NaN                 NaN
# cs_pp_53                                 NaN                 NaN
# cs_pp_114                                NaN                 NaN
# cs_pp_25                                 NaN                 NaN
# cs_pp_02                                 NaN                 NaN
# cs_pp_03                                 NaN                 NaN
# cs_pp_26                                 NaN                 NaN
# cs_pp_28                                 NaN                 NaN
# cs_pp_04                                 NaN                 NaN
# cs_pp_54                                 NaN                 NaN
# ctc_cfe_02                               NaN                 NaN
# ctc_exp_01                               NaN                 NaN
# cs_cfe_01                                NaN                 NaN
# ctg_aut_06                               NaN                 NaN
# ctg_cog_07                               NaN                 NaN
# ctg_pp_01                                NaN                 NaN
# ctg_pp_02                                NaN                 NaN
#
#                                 scheduled_outage_rate  capacity_limit_mw  \
# project_name
# cerro_prieto_i_u5                                14.1               28.2
# cerro_prieto_ii_central                          14.1              206.6
# cerro_prieto_iii_central                         14.1              206.6
# cerro_prieto_iv_central                          14.1               93.9
# cerro_prieto_fotovoltaica                         0.0                5.0
# cipres_tg                                         5.5               26.7
# mexicali                                          7.7              474.8
# mexicali_tg_1                                     5.5               25.4
# mexicali_tg_2                                     5.5               17.6
# mexicali_tg_3                                     5.5               17.6
# presidente_juarez_rosarito                        7.7              749.0
# presidente_juarez_rosarito5_tc                    7.1              149.8
# presidente_juarez_rosarito6_tc                    7.1              149.8
# tijuana_1_tg                                      5.5               29.3
# tijuana_2_tg                                      5.5               29.3
# tijuana_3_tg_150mw                                5.5              148.4
# tijuana_tg_central                                5.5              133.5
# baja_california_sur_i                             7.4              156.8
# ciudad_constitucion                               5.5               32.4
# guerrero_negro                                    5.5               12.2
# guerrero_negro_ii                                 7.4                9.9
# la_paz_tg1                                        5.5               17.6
# la_paz_tg2                                        5.5               24.4
# los_cabos_cfe_25000                               5.5               74.1
# los_cabos_cfe_30000                               5.5              102.8
# los_cabos_1_tg                                    5.5               29.3
# los_cabos_2_tg                                    5.5               26.7
# los_cabos_3_tg                                    5.5               26.6
# punta_prieta_ii_u1                                7.1               35.1
# punta_prieta_ii_u2                                7.1               35.1
# ...                                               ...                ...
# cs_pp_44                                          0.0               30.0
# cs_pp_45                                          0.0               30.0
# cs_pp_46                                          0.0               30.0
# cs_pp_17                                          0.0               25.0
# cs_pp_47                                          0.0               14.4
# cs_pp_48                                          0.0               14.4
# cs_pp_18                                          0.0                5.0
# cs_pp_21                                          0.0               26.7
# cs_pp_49                                          0.0               30.0
# cs_pp_50                                          0.0               30.0
# cs_pp_51                                          0.0               30.0
# cs_pp_52                                          0.0               29.4
# cs_pp_24                                          0.0               30.0
# cs_pp_113                                         0.0               30.0
# cs_pp_53                                          0.0               30.0
# cs_pp_114                                         0.0               30.0
# cs_pp_25                                          0.0               10.0
# cs_pp_02                                          0.0               15.0
# cs_pp_03                                          0.0               30.0
# cs_pp_26                                          0.0                6.3
# cs_pp_28                                          0.0                6.3
# cs_pp_04                                          0.0                3.5
# cs_pp_54                                          0.0               30.0
# ctc_cfe_02                                        7.1              314.5
# ctc_exp_01                                        7.1              133.5
# cs_cfe_01                                         0.0               13.9
# ctg_aut_06                                        5.5               93.2
# ctg_cog_07                                        5.5               12.7
# ctg_pp_01                                         5.5               29.3
# ctg_pp_02                                         5.5               29.3
#
#                                start_year  capacity_mw  overnight_cost  \
# project_name
# cerro_prieto_i_u5                     NaN         28.2             NaN
# cerro_prieto_ii_central               NaN        206.6             NaN
# cerro_prieto_iii_central              NaN        206.6             NaN
# cerro_prieto_iv_central               NaN         93.9             NaN
# cerro_prieto_fotovoltaica             NaN          5.0             NaN
# cipres_tg                             NaN         26.7             NaN
# mexicali                              NaN        474.8             NaN
# mexicali_tg_1                         NaN         25.4             NaN
# mexicali_tg_2                         NaN         17.6             NaN
# mexicali_tg_3                         NaN         17.6             NaN
# presidente_juarez_rosarito            NaN        749.0             NaN
# presidente_juarez_rosarito5_tc        NaN        149.8             NaN
# presidente_juarez_rosarito6_tc        NaN        149.8             NaN
# tijuana_1_tg                          NaN         29.3             NaN
# tijuana_2_tg                          NaN         29.3             NaN
# tijuana_3_tg_150mw                    NaN        148.4             NaN
# tijuana_tg_central                    NaN        133.5             NaN
# baja_california_sur_i                 NaN        156.8             NaN
# ciudad_constitucion                   NaN         32.4             NaN
# guerrero_negro                        NaN         12.2             NaN
# guerrero_negro_ii                     NaN          9.9             NaN
# la_paz_tg1                            NaN         17.6             NaN
# la_paz_tg2                            NaN         24.4             NaN
# los_cabos_cfe_25000                   NaN         74.1             NaN
# los_cabos_cfe_30000                   NaN        102.8             NaN
# los_cabos_1_tg                        NaN         29.3             NaN
# los_cabos_2_tg                        NaN         26.7             NaN
# los_cabos_3_tg                        NaN         26.6             NaN
# punta_prieta_ii_u1                    NaN         35.1             NaN
# punta_prieta_ii_u2                    NaN         35.1             NaN
# ...                                   ...          ...             ...
# cs_pp_44                          2016.00         30.0             NaN
# cs_pp_45                          2016.00         30.0             NaN
# cs_pp_46                          2016.00         30.0             NaN
# cs_pp_17                          2016.00         25.0             NaN
# cs_pp_47                          2016.00         14.4             NaN
# cs_pp_48                          2016.00         14.4             NaN
# cs_pp_18                          2016.00          5.0             NaN
# cs_pp_21                          2016.00         26.7             NaN
# cs_pp_49                          2016.00         30.0             NaN
# cs_pp_50                          2016.00         30.0             NaN
# cs_pp_51                          2016.00         30.0             NaN
# cs_pp_52                          2016.00         29.4             NaN
# cs_pp_24                          2016.00         30.0             NaN
# cs_pp_113                         2016.00         30.0             NaN
# cs_pp_53                          2016.00         30.0             NaN
# cs_pp_114                         2016.00         30.0             NaN
# cs_pp_25                          2016.00         10.0             NaN
# cs_pp_02                          2016.00         15.0             NaN
# cs_pp_03                          2016.00         30.0             NaN
# cs_pp_26                          2016.00          6.3             NaN
# cs_pp_28                          2016.00          6.3             NaN
# cs_pp_04                          2016.00          3.5             NaN
# cs_pp_54                          2016.00         30.0             NaN
# ctc_cfe_02                        2017.00        314.5             NaN
# ctc_exp_01                        2016.00        133.5             NaN
# cs_cfe_01                         2016.00         13.9             NaN
# ctg_aut_06                        2016.00         93.2             NaN
# ctg_cog_07                        2016.00         12.7             NaN
# ctg_pp_01                         2016.00         29.3             NaN
# ctg_pp_02                         2016.00         29.3             NaN
#
#                                 fixed_o_m  project_id  \
# project_name
# cerro_prieto_i_u5                     NaN         1.0
# cerro_prieto_ii_central               NaN         2.0
# cerro_prieto_iii_central              NaN         3.0
# cerro_prieto_iv_central               NaN         4.0
# cerro_prieto_fotovoltaica             NaN         5.0
# cipres_tg                             NaN         6.0
# mexicali                              NaN         7.0
# mexicali_tg_1                         NaN         8.0
# mexicali_tg_2                         NaN         9.0
# mexicali_tg_3                         NaN        10.0
# presidente_juarez_rosarito            NaN        11.0
# presidente_juarez_rosarito5_tc        NaN        12.0
# presidente_juarez_rosarito6_tc        NaN        13.0
# tijuana_1_tg                          NaN        14.0
# tijuana_2_tg                          NaN        15.0
# tijuana_3_tg_150mw                    NaN        16.0
# tijuana_tg_central                    NaN        17.0
# baja_california_sur_i                 NaN        18.0
# ciudad_constitucion                   NaN        19.0
# guerrero_negro                        NaN        20.0
# guerrero_negro_ii                     NaN        21.0
# la_paz_tg1                            NaN        22.0
# la_paz_tg2                            NaN        23.0
# los_cabos_cfe_25000                   NaN        24.0
# los_cabos_cfe_30000                   NaN        25.0
# los_cabos_1_tg                        NaN        26.0
# los_cabos_2_tg                        NaN        27.0
# los_cabos_3_tg                        NaN        28.0
# punta_prieta_ii_u1                    NaN        29.0
# punta_prieta_ii_u2                    NaN        30.0
# ...                                   ...         ...
# cs_pp_44                              NaN      1404.0
# cs_pp_45                              NaN      1405.0
# cs_pp_46                              NaN      1406.0
# cs_pp_17                              NaN      1407.0
# cs_pp_47                              NaN      1408.0
# cs_pp_48                              NaN      1409.0
# cs_pp_18                              NaN      1410.0
# cs_pp_21                              NaN      1411.0
# cs_pp_49                              NaN      1412.0
# cs_pp_50                              NaN      1413.0
# cs_pp_51                              NaN      1414.0
# cs_pp_52                              NaN      1415.0
# cs_pp_24                              NaN      1416.0
# cs_pp_113                             NaN      1417.0
# cs_pp_53                              NaN      1418.0
# cs_pp_114                             NaN      1419.0
# cs_pp_25                              NaN      1420.0
# cs_pp_02                              NaN      1421.0
# cs_pp_03                              NaN      1422.0
# cs_pp_26                              NaN      1423.0
# cs_pp_28                              NaN      1424.0
# cs_pp_04                              NaN      1425.0
# cs_pp_54                              NaN      1426.0
# ctc_cfe_02                            NaN      1607.0
# ctc_exp_01                            NaN      1608.0
# cs_cfe_01                             NaN      1609.0
# ctg_aut_06                            NaN      1610.0
# ctg_cog_07                            NaN      1615.0
# ctg_pp_01                             NaN      1617.0
# ctg_pp_02                             NaN      1618.0
#
#                                                  being_built   fuel_code  \
# project_name
# cerro_prieto_i_u5                                operational         NaN
# cerro_prieto_ii_central                          operational         NaN
# cerro_prieto_iii_central                         operational         NaN
# cerro_prieto_iv_central                          operational         NaN
# cerro_prieto_fotovoltaica                        operational         NaN
# cipres_tg                                        operational       d_bcn
# mexicali                                         operational    g_i_noro
# mexicali_tg_1                                    operational       d_bcn
# mexicali_tg_2                                    operational       d_bcn
# mexicali_tg_3                                    operational       d_bcn
# presidente_juarez_rosarito                       operational    g_i_noro
# presidente_juarez_rosarito5_tc                   operational    c_n_vizc
# presidente_juarez_rosarito6_tc                   operational    c_n_vizc
# tijuana_1_tg                                     operational  g_i_jovibn
# tijuana_2_tg                                     operational  g_i_jovibn
# tijuana_3_tg_150mw                               operational  g_i_jovibn
# tijuana_tg_central                               operational  g_i_jovibn
# baja_california_sur_i                            operational    c_n_chih
# ciudad_constitucion                              operational       d_bcn
# guerrero_negro                                   operational       d_bcn
# guerrero_negro_ii                                operational    c_n_vizc
# la_paz_tg1                                       operational       d_bcn
# la_paz_tg2                                       operational       d_bcn
# los_cabos_cfe_25000                              operational       d_bcn
# los_cabos_cfe_30000                              operational       d_bcn
# los_cabos_1_tg                                   operational       d_bcn
# los_cabos_2_tg                                   operational       d_bcn
# los_cabos_3_tg                                   operational       d_bcn
# punta_prieta_ii_u1                               operational       d_bcn
# punta_prieta_ii_u2                               operational       d_bcn
# ...                                                      ...         ...
# cs_pp_44                                        firm_project         NaN
# cs_pp_45                                        firm_project         NaN
# cs_pp_46                                        firm_project         NaN
# cs_pp_17                                        firm_project         NaN
# cs_pp_47                                        firm_project         NaN
# cs_pp_48                                        firm_project         NaN
# cs_pp_18                                        firm_project         NaN
# cs_pp_21                                        firm_project         NaN
# cs_pp_49                                        firm_project         NaN
# cs_pp_50                                        firm_project         NaN
# cs_pp_51                                        firm_project         NaN
# cs_pp_52                                        firm_project         NaN
# cs_pp_24                                        firm_project         NaN
# cs_pp_113                                       firm_project         NaN
# cs_pp_53                                        firm_project         NaN
# cs_pp_114                                       firm_project         NaN
# cs_pp_25                                        firm_project         NaN
# cs_pp_02                                        firm_project         NaN
# cs_pp_03                                        firm_project         NaN
# cs_pp_26                                        firm_project         NaN
# cs_pp_28                                        firm_project         NaN
# cs_pp_04                                        firm_project         NaN
# cs_pp_54                                        firm_project         NaN
# ctc_cfe_02                      rehabilitation_modernization    c_n_alta
# ctc_exp_01                                      firm_project     g_ahnrr
# cs_cfe_01                                       firm_project         NaN
# ctg_aut_06                                      firm_project   g_central
# ctg_cog_07                                      firm_project     g_2boca
# ctg_pp_01                                       firm_project   zzon_noro
# ctg_pp_02                                       firm_project   zzon_noro
#
#                                    fuel_oil         balancing_area
# project_name
# cerro_prieto_i_u5                       NaN            48-mexicali
# cerro_prieto_ii_central                 NaN            48-mexicali
# cerro_prieto_iii_central                NaN            48-mexicali
# cerro_prieto_iv_central                 NaN            48-mexicali
# cerro_prieto_fotovoltaica               NaN            48-mexicali
# cipres_tg                            diesel            47-ensenada
# mexicali                        natural_gas            48-mexicali
# mexicali_tg_1                        diesel            48-mexicali
# mexicali_tg_2                        diesel            48-mexicali
# mexicali_tg_3                        diesel            48-mexicali
# presidente_juarez_rosarito      natural_gas             46-tijuana
# presidente_juarez_rosarito5_tc     fuel_oil             46-tijuana
# presidente_juarez_rosarito6_tc     fuel_oil             46-tijuana
# tijuana_1_tg                    natural_gas             46-tijuana
# tijuana_2_tg                    natural_gas             46-tijuana
# tijuana_3_tg_150mw              natural_gas             46-tijuana
# tijuana_tg_central              natural_gas             46-tijuana
# baja_california_sur_i              fuel_oil              51-la_paz
# ciudad_constitucion                  diesel  50-villa_constitucion
# guerrero_negro                       diesel              53-mulege
# guerrero_negro_ii                  fuel_oil              53-mulege
# la_paz_tg1                           diesel              51-la_paz
# la_paz_tg2                           diesel              51-la_paz
# los_cabos_cfe_25000                  diesel           52-los_cabos
# los_cabos_cfe_30000                  diesel           52-los_cabos
# los_cabos_1_tg                       diesel           52-los_cabos
# los_cabos_2_tg                       diesel           52-los_cabos
# los_cabos_3_tg                       diesel           52-los_cabos
# punta_prieta_ii_u1                   diesel              51-la_paz
# punta_prieta_ii_u2                   diesel              51-la_paz
# ...                                     ...                    ...
# cs_pp_44                                NaN           30-queretaro
# cs_pp_45                                NaN           30-queretaro
# cs_pp_46                                NaN             03-obregon
# cs_pp_17                                NaN              51-la_paz
# cs_pp_47                                NaN         23-guadalajara
# cs_pp_48                                NaN         23-guadalajara
# cs_pp_18                                NaN              51-la_paz
# cs_pp_21                                NaN          01-hermosillo
# cs_pp_49                                NaN           30-queretaro
# cs_pp_50                                NaN           09-chihuahua
# cs_pp_51                                NaN          01-hermosillo
# cs_pp_52                                NaN       12-rio_escondido
# cs_pp_24                                NaN          01-hermosillo
# cs_pp_113                               NaN          01-hermosillo
# cs_pp_53                                NaN     25-san_luis_potosi
# cs_pp_114                               NaN           08-moctezuma
# cs_pp_25                                NaN             10-durango
# cs_pp_02                                NaN             10-durango
# cs_pp_03                                NaN             10-durango
# cs_pp_26                                NaN             10-durango
# cs_pp_28                                NaN             10-durango
# cs_pp_04                                NaN             10-durango
# cs_pp_54                                NaN           09-chihuahua
# ctc_cfe_02                         fuel_oil            19-huasteca
# ctc_exp_01                      natural_gas           16-monterrey
# cs_cfe_01                               NaN             02-cananea
# ctg_aut_06                      natural_gas             31-central
# ctg_cog_07                      natural_gas             38-tabasco
# ctg_pp_01                       natural_gas             02-cananea
# ctg_pp_02                       natural_gas             02-cananea
#
# [974 rows x 17 columns]

# %%
for i in df1.index.tolist():
    #setting auxiliary dataframe for plant gen_tech info
    df3=df2.loc[df1.loc[i,'gen_tech'],:]
    #iterating over the costs
    for name in ['fixed_o_m','variable_o_m','overnight_cost']:
        #selecting the costs according to the capacity and technology of the plant
        #try and except due to error with length of dataframe
        try: a=df3.loc[df3['capacity_mw']==nearest_value(lista(df2.loc[df1.loc[i,'gen_tech'],'capacity_mw'].tolist()),df1.loc[i,'capacity_mw'].astype('float'))]
        except KeyError: a=df3
        df1.loc[i,name]=float(a[name])
# Out:
#                                                     gen_tech  \
# project_name
# cerro_prieto_i_u5                                 geothermal
# cerro_prieto_ii_central                           geothermal
# cerro_prieto_iii_central                          geothermal
# cerro_prieto_iv_central                           geothermal
# cerro_prieto_fotovoltaica                              solar
# cipres_tg                                 gas_turbine_diesel
# mexicali                          combined_cycle_natural_gas
# mexicali_tg_1                             gas_turbine_diesel
# mexicali_tg_2                             gas_turbine_diesel
# mexicali_tg_3                             gas_turbine_diesel
# presidente_juarez_rosarito        combined_cycle_natural_gas
# presidente_juarez_rosarito5_tc              thermal_fuel_oil
# presidente_juarez_rosarito6_tc              thermal_fuel_oil
# tijuana_1_tg                         gas_turbine_natural_gas
# tijuana_2_tg                         gas_turbine_natural_gas
# tijuana_3_tg_150mw                   gas_turbine_natural_gas
# tijuana_tg_central                   gas_turbine_natural_gas
# baja_california_sur_i           internal_combustion_fuel_oil
# ciudad_constitucion                       gas_turbine_diesel
# guerrero_negro                            gas_turbine_diesel
# guerrero_negro_ii               internal_combustion_fuel_oil
# la_paz_tg1                                gas_turbine_diesel
# la_paz_tg2                                gas_turbine_diesel
# los_cabos_cfe_25000                       gas_turbine_diesel
# los_cabos_cfe_30000                       gas_turbine_diesel
# los_cabos_1_tg                            gas_turbine_diesel
# los_cabos_2_tg                            gas_turbine_diesel
# los_cabos_3_tg                            gas_turbine_diesel
# punta_prieta_ii_u1                            thermal_diesel
# punta_prieta_ii_u2                            thermal_diesel
# ...                                                      ...
# cs_pp_44                                               solar
# cs_pp_45                                               solar
# cs_pp_46                                               solar
# cs_pp_17                                               solar
# cs_pp_47                                               solar
# cs_pp_48                                               solar
# cs_pp_18                                               solar
# cs_pp_21                                               solar
# cs_pp_49                                               solar
# cs_pp_50                                               solar
# cs_pp_51                                               solar
# cs_pp_52                                               solar
# cs_pp_24                                               solar
# cs_pp_113                                              solar
# cs_pp_53                                               solar
# cs_pp_114                                              solar
# cs_pp_25                                               solar
# cs_pp_02                                               solar
# cs_pp_03                                               solar
# cs_pp_26                                               solar
# cs_pp_28                                               solar
# cs_pp_04                                               solar
# cs_pp_54                                               solar
# ctc_cfe_02                                  thermal_fuel_oil
# ctc_exp_01                               thermal_natural_gas
# cs_cfe_01                                         termosolar
# ctg_aut_06                           gas_turbine_natural_gas
# ctg_cog_07                           gas_turbine_natural_gas
# ctg_pp_01                            gas_turbine_natural_gas
# ctg_pp_02                            gas_turbine_natural_gas
#
#                                                     load_zone  \
# project_name
# cerro_prieto_i_u5                          08-baja_california
# cerro_prieto_ii_central                    08-baja_california
# cerro_prieto_iii_central                   08-baja_california
# cerro_prieto_iv_central                    08-baja_california
# cerro_prieto_fotovoltaica                  08-baja_california
# cipres_tg                                  08-baja_california
# mexicali                                   08-baja_california
# mexicali_tg_1                              08-baja_california
# mexicali_tg_2                              08-baja_california
# mexicali_tg_3                              08-baja_california
# presidente_juarez_rosarito                 08-baja_california
# presidente_juarez_rosarito5_tc             08-baja_california
# presidente_juarez_rosarito6_tc             08-baja_california
# tijuana_1_tg                               08-baja_california
# tijuana_2_tg                               08-baja_california
# tijuana_3_tg_150mw                         08-baja_california
# tijuana_tg_central                         08-baja_california
# baja_california_sur_i           09-baja_california_sur-la_paz
# ciudad_constitucion             09-baja_california_sur-la_paz
# guerrero_negro                  10-baja_california_sur-mulege
# guerrero_negro_ii               10-baja_california_sur-mulege
# la_paz_tg1                      09-baja_california_sur-la_paz
# la_paz_tg2                      09-baja_california_sur-la_paz
# los_cabos_cfe_25000             09-baja_california_sur-la_paz
# los_cabos_cfe_30000             09-baja_california_sur-la_paz
# los_cabos_1_tg                  09-baja_california_sur-la_paz
# los_cabos_2_tg                  09-baja_california_sur-la_paz
# los_cabos_3_tg                  09-baja_california_sur-la_paz
# punta_prieta_ii_u1              09-baja_california_sur-la_paz
# punta_prieta_ii_u2              09-baja_california_sur-la_paz
# ...                                                       ...
# cs_pp_44                                        03-occidental
# cs_pp_45                                        03-occidental
# cs_pp_46                                          04-noroeste
# cs_pp_17                        09-baja_california_sur-la_paz
# cs_pp_47                                        03-occidental
# cs_pp_48                                        03-occidental
# cs_pp_18                        09-baja_california_sur-la_paz
# cs_pp_21                                          04-noroeste
# cs_pp_49                                        03-occidental
# cs_pp_50                                             05-norte
# cs_pp_51                                          04-noroeste
# cs_pp_52                                           06-noreste
# cs_pp_24                                          04-noroeste
# cs_pp_113                                         04-noroeste
# cs_pp_53                                        03-occidental
# cs_pp_114                                            05-norte
# cs_pp_25                                             05-norte
# cs_pp_02                                             05-norte
# cs_pp_03                                             05-norte
# cs_pp_26                                             05-norte
# cs_pp_28                                             05-norte
# cs_pp_04                                             05-norte
# cs_pp_54                                             05-norte
# ctc_cfe_02                                         06-noreste
# ctc_exp_01                                         06-noreste
# cs_cfe_01                                         04-noroeste
# ctg_aut_06                                         01-central
# ctg_cog_07                                        02-oriental
# ctg_pp_01                                         04-noroeste
# ctg_pp_02                                         04-noroeste
#
#                                 full_load_heat_rate  connect_cost_per_mw  \
# project_name
# cerro_prieto_i_u5                               0.0                  0.0
# cerro_prieto_ii_central                         0.0                  0.0
# cerro_prieto_iii_central                        0.0                  0.0
# cerro_prieto_iv_central                         0.0                  0.0
# cerro_prieto_fotovoltaica                       0.0                  0.0
# cipres_tg                                      18.2                  0.0
# mexicali                                        7.9                  0.0
# mexicali_tg_1                                  22.3                  0.0
# mexicali_tg_2                                  22.3                  0.0
# mexicali_tg_3                                  22.3                  0.0
# presidente_juarez_rosarito                     11.0                  0.0
# presidente_juarez_rosarito5_tc                 11.0                  0.0
# presidente_juarez_rosarito6_tc                 11.0                  0.0
# tijuana_1_tg                                   10.8                  0.0
# tijuana_2_tg                                   10.8                  0.0
# tijuana_3_tg_150mw                             10.8                  0.0
# tijuana_tg_central                             10.8                  0.0
# baja_california_sur_i                          10.3                  0.0
# ciudad_constitucion                            19.2                  0.0
# guerrero_negro                                 27.8                  0.0
# guerrero_negro_ii                              10.3                  0.0
# la_paz_tg1                                     18.2                  0.0
# la_paz_tg2                                     18.2                  0.0
# los_cabos_cfe_25000                             9.6                  0.0
# los_cabos_cfe_30000                            11.4                  0.0
# los_cabos_1_tg                                 18.1                  0.0
# los_cabos_2_tg                                 18.1                  0.0
# los_cabos_3_tg                                 18.1                  0.0
# punta_prieta_ii_u1                             12.0                  0.0
# punta_prieta_ii_u2                             12.0                  0.0
# ...                                             ...                  ...
# cs_pp_44                                        0.0                  0.0
# cs_pp_45                                        0.0                  0.0
# cs_pp_46                                        0.0                  0.0
# cs_pp_17                                        0.0                  0.0
# cs_pp_47                                        0.0                  0.0
# cs_pp_48                                        0.0                  0.0
# cs_pp_18                                        0.0                  0.0
# cs_pp_21                                        0.0                  0.0
# cs_pp_49                                        0.0                  0.0
# cs_pp_50                                        0.0                  0.0
# cs_pp_51                                        0.0                  0.0
# cs_pp_52                                        0.0                  0.0
# cs_pp_24                                        0.0                  0.0
# cs_pp_113                                       0.0                  0.0
# cs_pp_53                                        0.0                  0.0
# cs_pp_114                                       0.0                  0.0
# cs_pp_25                                        0.0                  0.0
# cs_pp_02                                        0.0                  0.0
# cs_pp_03                                        0.0                  0.0
# cs_pp_26                                        0.0                  0.0
# cs_pp_28                                        0.0                  0.0
# cs_pp_04                                        0.0                  0.0
# cs_pp_54                                        0.0                  0.0
# ctc_cfe_02                                     10.3                  0.0
# ctc_exp_01                                      9.3                  0.0
# cs_cfe_01                                       0.0                  0.0
# ctg_aut_06                                     11.8                  0.0
# ctg_cog_07                                      9.6                  0.0
# ctg_pp_01                                       9.6                  0.0
# ctg_pp_02                                       9.6                  0.0
#
#                                 variable_o_m  forced_outage_rate  \
# project_name
# cerro_prieto_i_u5                       0.06                 NaN
# cerro_prieto_ii_central                 0.06                 NaN
# cerro_prieto_iii_central                0.06                 NaN
# cerro_prieto_iv_central                 0.06                 NaN
# cerro_prieto_fotovoltaica               0.00                 NaN
# cipres_tg                               3.08                 NaN
# mexicali                                2.73                 NaN
# mexicali_tg_1                           3.08                 NaN
# mexicali_tg_2                           3.08                 NaN
# mexicali_tg_3                           3.08                 NaN
# presidente_juarez_rosarito              2.77                 NaN
# presidente_juarez_rosarito5_tc          3.13                 NaN
# presidente_juarez_rosarito6_tc          3.13                 NaN
# tijuana_1_tg                            3.19                 NaN
# tijuana_2_tg                            3.19                 NaN
# tijuana_3_tg_150mw                      3.20                 NaN
# tijuana_tg_central                      4.12                 NaN
# baja_california_sur_i                   8.01                 NaN
# ciudad_constitucion                     3.08                 NaN
# guerrero_negro                          3.08                 NaN
# guerrero_negro_ii                       3.16                 NaN
# la_paz_tg1                              3.08                 NaN
# la_paz_tg2                              3.08                 NaN
# los_cabos_cfe_25000                     3.08                 NaN
# los_cabos_cfe_30000                     3.08                 NaN
# los_cabos_1_tg                          3.08                 NaN
# los_cabos_2_tg                          3.08                 NaN
# los_cabos_3_tg                          3.08                 NaN
# punta_prieta_ii_u1                      3.94                 NaN
# punta_prieta_ii_u2                      3.94                 NaN
# ...                                      ...                 ...
# cs_pp_44                                0.00                 NaN
# cs_pp_45                                0.00                 NaN
# cs_pp_46                                0.00                 NaN
# cs_pp_17                                0.00                 NaN
# cs_pp_47                                0.00                 NaN
# cs_pp_48                                0.00                 NaN
# cs_pp_18                                0.00                 NaN
# cs_pp_21                                0.00                 NaN
# cs_pp_49                                0.00                 NaN
# cs_pp_50                                0.00                 NaN
# cs_pp_51                                0.00                 NaN
# cs_pp_52                                0.00                 NaN
# cs_pp_24                                0.00                 NaN
# cs_pp_113                               0.00                 NaN
# cs_pp_53                                0.00                 NaN
# cs_pp_114                               0.00                 NaN
# cs_pp_25                                0.00                 NaN
# cs_pp_02                                0.00                 NaN
# cs_pp_03                                0.00                 NaN
# cs_pp_26                                0.00                 NaN
# cs_pp_28                                0.00                 NaN
# cs_pp_04                                0.00                 NaN
# cs_pp_54                                0.00                 NaN
# ctc_cfe_02                              2.20                 NaN
# ctc_exp_01                              3.13                 NaN
# cs_cfe_01                                NaN                 NaN
# ctg_aut_06                              4.19                 NaN
# ctg_cog_07                              3.19                 NaN
# ctg_pp_01                               3.19                 NaN
# ctg_pp_02                               3.19                 NaN
#
#                                 scheduled_outage_rate  capacity_limit_mw  \
# project_name
# cerro_prieto_i_u5                                14.1               28.2
# cerro_prieto_ii_central                          14.1              206.6
# cerro_prieto_iii_central                         14.1              206.6
# cerro_prieto_iv_central                          14.1               93.9
# cerro_prieto_fotovoltaica                         0.0                5.0
# cipres_tg                                         5.5               26.7
# mexicali                                          7.7              474.8
# mexicali_tg_1                                     5.5               25.4
# mexicali_tg_2                                     5.5               17.6
# mexicali_tg_3                                     5.5               17.6
# presidente_juarez_rosarito                        7.7              749.0
# presidente_juarez_rosarito5_tc                    7.1              149.8
# presidente_juarez_rosarito6_tc                    7.1              149.8
# tijuana_1_tg                                      5.5               29.3
# tijuana_2_tg                                      5.5               29.3
# tijuana_3_tg_150mw                                5.5              148.4
# tijuana_tg_central                                5.5              133.5
# baja_california_sur_i                             7.4              156.8
# ciudad_constitucion                               5.5               32.4
# guerrero_negro                                    5.5               12.2
# guerrero_negro_ii                                 7.4                9.9
# la_paz_tg1                                        5.5               17.6
# la_paz_tg2                                        5.5               24.4
# los_cabos_cfe_25000                               5.5               74.1
# los_cabos_cfe_30000                               5.5              102.8
# los_cabos_1_tg                                    5.5               29.3
# los_cabos_2_tg                                    5.5               26.7
# los_cabos_3_tg                                    5.5               26.6
# punta_prieta_ii_u1                                7.1               35.1
# punta_prieta_ii_u2                                7.1               35.1
# ...                                               ...                ...
# cs_pp_44                                          0.0               30.0
# cs_pp_45                                          0.0               30.0
# cs_pp_46                                          0.0               30.0
# cs_pp_17                                          0.0               25.0
# cs_pp_47                                          0.0               14.4
# cs_pp_48                                          0.0               14.4
# cs_pp_18                                          0.0                5.0
# cs_pp_21                                          0.0               26.7
# cs_pp_49                                          0.0               30.0
# cs_pp_50                                          0.0               30.0
# cs_pp_51                                          0.0               30.0
# cs_pp_52                                          0.0               29.4
# cs_pp_24                                          0.0               30.0
# cs_pp_113                                         0.0               30.0
# cs_pp_53                                          0.0               30.0
# cs_pp_114                                         0.0               30.0
# cs_pp_25                                          0.0               10.0
# cs_pp_02                                          0.0               15.0
# cs_pp_03                                          0.0               30.0
# cs_pp_26                                          0.0                6.3
# cs_pp_28                                          0.0                6.3
# cs_pp_04                                          0.0                3.5
# cs_pp_54                                          0.0               30.0
# ctc_cfe_02                                        7.1              314.5
# ctc_exp_01                                        7.1              133.5
# cs_cfe_01                                         0.0               13.9
# ctg_aut_06                                        5.5               93.2
# ctg_cog_07                                        5.5               12.7
# ctg_pp_01                                         5.5               29.3
# ctg_pp_02                                         5.5               29.3
#
#                                start_year  capacity_mw  overnight_cost  \
# project_name
# cerro_prieto_i_u5                     NaN         28.2          2261.0
# cerro_prieto_ii_central               NaN        206.6          2261.0
# cerro_prieto_iii_central              NaN        206.6          2261.0
# cerro_prieto_iv_central               NaN         93.9          2261.0
# cerro_prieto_fotovoltaica             NaN          5.0          2128.0
# cipres_tg                             NaN         26.7          1035.0
# mexicali                              NaN        474.8           765.0
# mexicali_tg_1                         NaN         25.4          1035.0
# mexicali_tg_2                         NaN         17.6          1035.0
# mexicali_tg_3                         NaN         17.6          1035.0
# presidente_juarez_rosarito            NaN        749.0           785.0
# presidente_juarez_rosarito5_tc        NaN        149.8          1607.0
# presidente_juarez_rosarito6_tc        NaN        149.8          1607.0
# tijuana_1_tg                          NaN         29.3          1059.0
# tijuana_2_tg                          NaN         29.3          1059.0
# tijuana_3_tg_150mw                    NaN        148.4           573.0
# tijuana_tg_central                    NaN        133.5          1063.0
# baja_california_sur_i                 NaN        156.8          2706.0
# ciudad_constitucion                   NaN         32.4          1035.0
# guerrero_negro                        NaN         12.2          1035.0
# guerrero_negro_ii                     NaN          9.9          2960.0
# la_paz_tg1                            NaN         17.6          1035.0
# la_paz_tg2                            NaN         24.4          1035.0
# los_cabos_cfe_25000                   NaN         74.1          1035.0
# los_cabos_cfe_30000                   NaN        102.8          1035.0
# los_cabos_1_tg                        NaN         29.3          1035.0
# los_cabos_2_tg                        NaN         26.7          1035.0
# los_cabos_3_tg                        NaN         26.6          1035.0
# punta_prieta_ii_u1                    NaN         35.1          2018.0
# punta_prieta_ii_u2                    NaN         35.1          2018.0
# ...                                   ...          ...             ...
# cs_pp_44                          2016.00         30.0          2128.0
# cs_pp_45                          2016.00         30.0          2128.0
# cs_pp_46                          2016.00         30.0          2128.0
# cs_pp_17                          2016.00         25.0          2128.0
# cs_pp_47                          2016.00         14.4          2128.0
# cs_pp_48                          2016.00         14.4          2128.0
# cs_pp_18                          2016.00          5.0          2128.0
# cs_pp_21                          2016.00         26.7          2128.0
# cs_pp_49                          2016.00         30.0          2128.0
# cs_pp_50                          2016.00         30.0          2128.0
# cs_pp_51                          2016.00         30.0          2128.0
# cs_pp_52                          2016.00         29.4          2128.0
# cs_pp_24                          2016.00         30.0          2128.0
# cs_pp_113                         2016.00         30.0          2128.0
# cs_pp_53                          2016.00         30.0          2128.0
# cs_pp_114                         2016.00         30.0          2128.0
# cs_pp_25                          2016.00         10.0          2128.0
# cs_pp_02                          2016.00         15.0          2128.0
# cs_pp_03                          2016.00         30.0          2128.0
# cs_pp_26                          2016.00          6.3          2128.0
# cs_pp_28                          2016.00          6.3          2128.0
# cs_pp_04                          2016.00          3.5          2128.0
# cs_pp_54                          2016.00         30.0          2128.0
# ctc_cfe_02                        2017.00        314.5          1309.0
# ctc_exp_01                        2016.00        133.5          1607.0
# cs_cfe_01                         2016.00         13.9             NaN
# ctg_aut_06                        2016.00         93.2           755.0
# ctg_cog_07                        2016.00         12.7          1059.0
# ctg_pp_01                         2016.00         29.3          1059.0
# ctg_pp_02                         2016.00         29.3          1059.0
#
#                                 fixed_o_m  project_id  \
# project_name
# cerro_prieto_i_u5                 111.839         1.0
# cerro_prieto_ii_central           111.839         2.0
# cerro_prieto_iii_central          111.839         3.0
# cerro_prieto_iv_central           111.839         4.0
# cerro_prieto_fotovoltaica          19.000         5.0
# cipres_tg                          20.058         6.0
# mexicali                           15.471         7.0
# mexicali_tg_1                      20.058         8.0
# mexicali_tg_2                      20.058         9.0
# mexicali_tg_3                      20.058        10.0
# presidente_juarez_rosarito         15.741        11.0
# presidente_juarez_rosarito5_tc     35.183        12.0
# presidente_juarez_rosarito6_tc     35.183        13.0
# tijuana_1_tg                       28.477        14.0
# tijuana_2_tg                       28.477        15.0
# tijuana_3_tg_150mw                  7.102        16.0
# tijuana_tg_central                 35.183        17.0
# baja_california_sur_i              61.852        18.0
# ciudad_constitucion                20.058        19.0
# guerrero_negro                     20.058        20.0
# guerrero_negro_ii                  28.044        21.0
# la_paz_tg1                         20.058        22.0
# la_paz_tg2                         20.058        23.0
# los_cabos_cfe_25000                20.058        24.0
# los_cabos_cfe_30000                20.058        25.0
# los_cabos_1_tg                     20.058        26.0
# los_cabos_2_tg                     20.058        27.0
# los_cabos_3_tg                     20.058        28.0
# punta_prieta_ii_u1                 44.254        29.0
# punta_prieta_ii_u2                 44.254        30.0
# ...                                   ...         ...
# cs_pp_44                           19.000      1404.0
# cs_pp_45                           19.000      1405.0
# cs_pp_46                           19.000      1406.0
# cs_pp_17                           19.000      1407.0
# cs_pp_47                           19.000      1408.0
# cs_pp_48                           19.000      1409.0
# cs_pp_18                           19.000      1410.0
# cs_pp_21                           19.000      1411.0
# cs_pp_49                           19.000      1412.0
# cs_pp_50                           19.000      1413.0
# cs_pp_51                           19.000      1414.0
# cs_pp_52                           19.000      1415.0
# cs_pp_24                           19.000      1416.0
# cs_pp_113                          19.000      1417.0
# cs_pp_53                           19.000      1418.0
# cs_pp_114                          19.000      1419.0
# cs_pp_25                           19.000      1420.0
# cs_pp_02                           19.000      1421.0
# cs_pp_03                           19.000      1422.0
# cs_pp_26                           19.000      1423.0
# cs_pp_28                           19.000      1424.0
# cs_pp_04                           19.000      1425.0
# cs_pp_54                           19.000      1426.0
# ctc_cfe_02                         28.477      1607.0
# ctc_exp_01                         35.183      1608.0
# cs_cfe_01                             NaN      1609.0
# ctg_aut_06                          8.517      1610.0
# ctg_cog_07                         28.477      1615.0
# ctg_pp_01                          28.477      1617.0
# ctg_pp_02                          28.477      1618.0
#
#                                                  being_built   fuel_code  \
# project_name
# cerro_prieto_i_u5                                operational         NaN
# cerro_prieto_ii_central                          operational         NaN
# cerro_prieto_iii_central                         operational         NaN
# cerro_prieto_iv_central                          operational         NaN
# cerro_prieto_fotovoltaica                        operational         NaN
# cipres_tg                                        operational       d_bcn
# mexicali                                         operational    g_i_noro
# mexicali_tg_1                                    operational       d_bcn
# mexicali_tg_2                                    operational       d_bcn
# mexicali_tg_3                                    operational       d_bcn
# presidente_juarez_rosarito                       operational    g_i_noro
# presidente_juarez_rosarito5_tc                   operational    c_n_vizc
# presidente_juarez_rosarito6_tc                   operational    c_n_vizc
# tijuana_1_tg                                     operational  g_i_jovibn
# tijuana_2_tg                                     operational  g_i_jovibn
# tijuana_3_tg_150mw                               operational  g_i_jovibn
# tijuana_tg_central                               operational  g_i_jovibn
# baja_california_sur_i                            operational    c_n_chih
# ciudad_constitucion                              operational       d_bcn
# guerrero_negro                                   operational       d_bcn
# guerrero_negro_ii                                operational    c_n_vizc
# la_paz_tg1                                       operational       d_bcn
# la_paz_tg2                                       operational       d_bcn
# los_cabos_cfe_25000                              operational       d_bcn
# los_cabos_cfe_30000                              operational       d_bcn
# los_cabos_1_tg                                   operational       d_bcn
# los_cabos_2_tg                                   operational       d_bcn
# los_cabos_3_tg                                   operational       d_bcn
# punta_prieta_ii_u1                               operational       d_bcn
# punta_prieta_ii_u2                               operational       d_bcn
# ...                                                      ...         ...
# cs_pp_44                                        firm_project         NaN
# cs_pp_45                                        firm_project         NaN
# cs_pp_46                                        firm_project         NaN
# cs_pp_17                                        firm_project         NaN
# cs_pp_47                                        firm_project         NaN
# cs_pp_48                                        firm_project         NaN
# cs_pp_18                                        firm_project         NaN
# cs_pp_21                                        firm_project         NaN
# cs_pp_49                                        firm_project         NaN
# cs_pp_50                                        firm_project         NaN
# cs_pp_51                                        firm_project         NaN
# cs_pp_52                                        firm_project         NaN
# cs_pp_24                                        firm_project         NaN
# cs_pp_113                                       firm_project         NaN
# cs_pp_53                                        firm_project         NaN
# cs_pp_114                                       firm_project         NaN
# cs_pp_25                                        firm_project         NaN
# cs_pp_02                                        firm_project         NaN
# cs_pp_03                                        firm_project         NaN
# cs_pp_26                                        firm_project         NaN
# cs_pp_28                                        firm_project         NaN
# cs_pp_04                                        firm_project         NaN
# cs_pp_54                                        firm_project         NaN
# ctc_cfe_02                      rehabilitation_modernization    c_n_alta
# ctc_exp_01                                      firm_project     g_ahnrr
# cs_cfe_01                                       firm_project         NaN
# ctg_aut_06                                      firm_project   g_central
# ctg_cog_07                                      firm_project     g_2boca
# ctg_pp_01                                       firm_project   zzon_noro
# ctg_pp_02                                       firm_project   zzon_noro
#
#                                    fuel_oil         balancing_area
# project_name
# cerro_prieto_i_u5                       NaN            48-mexicali
# cerro_prieto_ii_central                 NaN            48-mexicali
# cerro_prieto_iii_central                NaN            48-mexicali
# cerro_prieto_iv_central                 NaN            48-mexicali
# cerro_prieto_fotovoltaica               NaN            48-mexicali
# cipres_tg                            diesel            47-ensenada
# mexicali                        natural_gas            48-mexicali
# mexicali_tg_1                        diesel            48-mexicali
# mexicali_tg_2                        diesel            48-mexicali
# mexicali_tg_3                        diesel            48-mexicali
# presidente_juarez_rosarito      natural_gas             46-tijuana
# presidente_juarez_rosarito5_tc     fuel_oil             46-tijuana
# presidente_juarez_rosarito6_tc     fuel_oil             46-tijuana
# tijuana_1_tg                    natural_gas             46-tijuana
# tijuana_2_tg                    natural_gas             46-tijuana
# tijuana_3_tg_150mw              natural_gas             46-tijuana
# tijuana_tg_central              natural_gas             46-tijuana
# baja_california_sur_i              fuel_oil              51-la_paz
# ciudad_constitucion                  diesel  50-villa_constitucion
# guerrero_negro                       diesel              53-mulege
# guerrero_negro_ii                  fuel_oil              53-mulege
# la_paz_tg1                           diesel              51-la_paz
# la_paz_tg2                           diesel              51-la_paz
# los_cabos_cfe_25000                  diesel           52-los_cabos
# los_cabos_cfe_30000                  diesel           52-los_cabos
# los_cabos_1_tg                       diesel           52-los_cabos
# los_cabos_2_tg                       diesel           52-los_cabos
# los_cabos_3_tg                       diesel           52-los_cabos
# punta_prieta_ii_u1                   diesel              51-la_paz
# punta_prieta_ii_u2                   diesel              51-la_paz
# ...                                     ...                    ...
# cs_pp_44                                NaN           30-queretaro
# cs_pp_45                                NaN           30-queretaro
# cs_pp_46                                NaN             03-obregon
# cs_pp_17                                NaN              51-la_paz
# cs_pp_47                                NaN         23-guadalajara
# cs_pp_48                                NaN         23-guadalajara
# cs_pp_18                                NaN              51-la_paz
# cs_pp_21                                NaN          01-hermosillo
# cs_pp_49                                NaN           30-queretaro
# cs_pp_50                                NaN           09-chihuahua
# cs_pp_51                                NaN          01-hermosillo
# cs_pp_52                                NaN       12-rio_escondido
# cs_pp_24                                NaN          01-hermosillo
# cs_pp_113                               NaN          01-hermosillo
# cs_pp_53                                NaN     25-san_luis_potosi
# cs_pp_114                               NaN           08-moctezuma
# cs_pp_25                                NaN             10-durango
# cs_pp_02                                NaN             10-durango
# cs_pp_03                                NaN             10-durango
# cs_pp_26                                NaN             10-durango
# cs_pp_28                                NaN             10-durango
# cs_pp_04                                NaN             10-durango
# cs_pp_54                                NaN           09-chihuahua
# ctc_cfe_02                         fuel_oil            19-huasteca
# ctc_exp_01                      natural_gas           16-monterrey
# cs_cfe_01                               NaN             02-cananea
# ctg_aut_06                      natural_gas             31-central
# ctg_cog_07                      natural_gas             38-tabasco
# ctg_pp_01                       natural_gas             02-cananea
# ctg_pp_02                       natural_gas             02-cananea
#
# [974 rows x 17 columns]

# %%
#export data
df1.to_csv('data/GenerationPlantsWithCosts.csv')
