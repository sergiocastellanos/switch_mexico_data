# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("data/PowerPlantsWithCosts.csv")
df2=df1[df1['gen_tech'].isin(['wind'])]
df2=df2[df2['balancing_area'] != "00-autoabasto"]
df3=df1[df1['gen_tech'].isin(['solar'])]
renewable=df2['project_name'].tolist()+df3['project_name'].tolist()
time=pd.read_csv('../Main Tabs/timepoints.tab',sep="\t")
df=pd.DataFrame(index=range(time.shape[0]*len(renewable)),columns=['PROJECT','timepoint','proj_max_capacity_factor'])

# %%
renewable=df2['project_name'].tolist()+df3['project_name'].tolist()
for name in renewable:
    print renewable.index(name)
    df4=pd.read_csv('data/renewable simulations/{0}.csv'.format(name),index_col=range(3))
    df.loc[range(renewable.index(name)*time.shape[0],((renewable.index(name)+1)*time.shape[0])),'PROJECT']=name
    for index, row in time.iterrows():
        date=str(row['timestamp'])
        i=index +renewable.index(name)*time.shape[0]
        df.loc[index,'timepoint']=index
        df.loc[index,'proj_max_capacity_factor']=df4.loc[(int(date[4:6]),int(date[6:8]),int(date[8:10])),'capacity_factor']
df.to_csv('../Main Tabs/variable_capacity_factors.tab',sep="\t",index=False)

# %%
df.dropna()
# Out:
#                     PROJECT timepoint proj_max_capacity_factor
# 0     guerrero_negro_eolica         0                        0
# 1     guerrero_negro_eolica         1                        0
# 2     guerrero_negro_eolica         2                        0
# 3     guerrero_negro_eolica         3                        0
# 4     guerrero_negro_eolica         4                        0
# 5     guerrero_negro_eolica         5                        0
# 6     guerrero_negro_eolica         6                 0.251749
# 7     guerrero_negro_eolica         7                 0.416071
# 8     guerrero_negro_eolica         8                        0
# 9     guerrero_negro_eolica         9                        0
# 10    guerrero_negro_eolica        10                        0
# 11    guerrero_negro_eolica        11                        0
# 12    guerrero_negro_eolica        12                        0
# 13    guerrero_negro_eolica        13                        0
# 14    guerrero_negro_eolica        14                        0
# 15    guerrero_negro_eolica        15                        0
# 16    guerrero_negro_eolica        16                        0
# 17    guerrero_negro_eolica        17                        0
# 18    guerrero_negro_eolica        18                        0
# 19    guerrero_negro_eolica        19                 0.461606
# 20    guerrero_negro_eolica        20                 0.291335
# 21    guerrero_negro_eolica        21                        0
# 22    guerrero_negro_eolica        22                        0
# 23    guerrero_negro_eolica        23                        0
# 24    guerrero_negro_eolica        24                        0
# 25    guerrero_negro_eolica        25                        0
# 26    guerrero_negro_eolica        26                        0
# 27    guerrero_negro_eolica        27                        0
# 28    guerrero_negro_eolica        28                        0
# 29    guerrero_negro_eolica        29                        0
# ...                     ...       ...                      ...
# 4290  guerrero_negro_eolica      4290                        0
# 4291  guerrero_negro_eolica      4291                 0.454516
# 4292  guerrero_negro_eolica      4292                 0.197754
# 4293  guerrero_negro_eolica      4293                        0
# 4294  guerrero_negro_eolica      4294                        0
# 4295  guerrero_negro_eolica      4295                        0
# 4296  guerrero_negro_eolica      4296                        0
# 4297  guerrero_negro_eolica      4297                        0
# 4298  guerrero_negro_eolica      4298                        0
# 4299  guerrero_negro_eolica      4299                        0
# 4300  guerrero_negro_eolica      4300                        0
# 4301  guerrero_negro_eolica      4301                        0
# 4302  guerrero_negro_eolica      4302                0.0177927
# 4303  guerrero_negro_eolica      4303                 0.223295
# 4304  guerrero_negro_eolica      4304                        0
# 4305  guerrero_negro_eolica      4305                        0
# 4306  guerrero_negro_eolica      4306                        0
# 4307  guerrero_negro_eolica      4307                        0
# 4308  guerrero_negro_eolica      4308                        0
# 4309  guerrero_negro_eolica      4309                        0
# 4310  guerrero_negro_eolica      4310                        0
# 4311  guerrero_negro_eolica      4311                        0
# 4312  guerrero_negro_eolica      4312                        0
# 4313  guerrero_negro_eolica      4313                        0
# 4314  guerrero_negro_eolica      4314                        0
# 4315  guerrero_negro_eolica      4315                 0.107428
# 4316  guerrero_negro_eolica      4316                 0.405349
# 4317  guerrero_negro_eolica      4317                        0
# 4318  guerrero_negro_eolica      4318                        0
# 4319  guerrero_negro_eolica      4319                        0
#
# [4320 rows x 3 columns]
